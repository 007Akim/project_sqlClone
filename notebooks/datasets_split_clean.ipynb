# %%
import requests
import pandas as pd
import re

# %%
url = 'https://cdn.jsdelivr.net/gh/akabab/superhero-api@0.3.0/api/all.json'

response = requests.get(url)

all_superheroes_data = response.json()
df = pd.DataFrame(all_superheroes_data)

# %%
df.dropna(inplace=True)
df.drop(columns=['work', 'connections', 'images'], inplace=True)

# %%
powerstats_df = pd.json_normalize(df['powerstats'])

appearance_df = pd.json_normalize(df['appearance'])

biography_df = pd.json_normalize(df['biography'])

combined_df = pd.concat([df[['id', 'name', 'slug']], powerstats_df, appearance_df,biography_df], axis=1)

# %%
combined_df.dropna(inplace=True)

# %%
skills_columns = ['intelligence', 'strength', 'speed', 'durability', 'power', 'combat']

combined_df.insert(9, 'Overall PS', combined_df[skills_columns].sum(axis=1))

# %%
combined_df
# Out:
#       id             name                 slug  intelligence  strength  speed  \
# 0      1           A-Bomb             1-a-bomb            38       100     17
# 1      2       Abe Sapien         2-abe-sapien            88        28     35
# 2      3         Abin Sur           3-abin-sur            50        90     53
# 3      4      Abomination        4-abomination            63        80     53
# 4      5          Abraxas            5-abraxas            88        63     83
# ..   ...              ...                  ...           ...       ...    ...
# 557  726     Yellowjacket     726-yellowjacket            88        10     12
# 558  727  Yellowjacket II  727-yellowjacket-ii            50        10     35
# 559  728             Ymir             728-ymir            50       100     27
# 560  729             Yoda             729-yoda            88        52     33
# 561  730          Zatanna          730-zatanna            81        10     23
#
#      durability  power  combat  Overall PS  ...            weight eyeColor  \
# 0            80     24      64         323  ...  [980 lb, 441 kg]   Yellow
# 1            65    100      85         401  ...   [145 lb, 65 kg]     Blue
# 2            64     99      65         421  ...   [200 lb, 90 kg]     Blue
# 3            90     62      95         443  ...  [980 lb, 441 kg]    Green
# 4           100    100      55         489  ...      [- lb, 0 kg]     Blue
# ..          ...    ...     ...         ...  ...               ...      ...
# 557          28     12      14         164  ...   [185 lb, 83 kg]     Blue
# 558          28     31      28         182  ...   [115 lb, 52 kg]     Blue
# 559         100     98      28         403  ...      [- lb, 0 kg]    White
# 560          25    100      90         388  ...    [38 lb, 17 kg]    Brown
# 561          28    100      56         298  ...   [127 lb, 57 kg]     Blue
#
#             hairColor                fullName  \
# 0             No Hair  Richard Milhouse Jones
# 1             No Hair          Abraham Sapien
# 2             No Hair
# 3             No Hair            Emil Blonsky
# 4               Black                 Abraxas
# ..                ...                     ...
# 557             Blond                Hank Pym
# 558  Strawberry Blond             Rita DeMara
# 559           No Hair                    Ymir
# 560             White                    Yoda
# 561             Black          Zatanna Zatara
#
#                                 alterEgos  \
# 0                    No alter egos found.
# 1                    No alter egos found.
# 2                    No alter egos found.
# 3                    No alter egos found.
# 4                    No alter egos found.
# ..                                    ...
# 557  Ant-Man, Giant-Man, Goliath, Wasp II
# 558                  No alter egos found.
# 559                  No alter egos found.
# 560                  No alter egos found.
# 561                  No alter egos found.
#
#                                                aliases        placeOfBirth  \
# 0                                         [Rick Jones]  Scarsdale, Arizona
# 1    [Langdon Everett Caul, Abraham Sapien, Langdon...                   -
# 2                                             [Lagzia]              Ungara
# 3                       [Agent R-7, Ravager of Worlds]  Zagreb, Yugoslavia
# 4                                                  [-]     Within Eternity
# ..                                                 ...                 ...
# 557                                         [Hank Pym]  Elmsford, New York
# 558                                                [-]                   -
# 559                                        [Aurgelmir]          Niffleheim
# 560                                                [-]                   -
# 561                                                [-]                   -
#
#                                        firstAppearance          publisher  \
# 0              Hulk Vol 2 #2 (April, 2008) (as A-Bomb)      Marvel Comics
# 1                  Hellboy: Seed of Destruction (1993)  Dark Horse Comics
# 2                         Showcase #22 (October, 1959)          DC Comics
# 3                                Tales to Astonish #90      Marvel Comics
# 4                          Fantastic Four Annual #2001      Marvel Comics
# ..                                                 ...                ...
# 557  (as Pym) TALES TO ASTONISH #27, (as Ant-Man) T...            Ant-Man
# 558                                      Avengers #264      Marvel Comics
# 559                           JOURNEY INTO MYSTERY #97      Marvel Comics
# 560  Star Wars: Episode V - The Empire Strikes Back...       George Lucas
# 561                                         Hawkman #4          DC Comics
#
#     alignment
# 0        good
# 1        good
# 2        good
# 3         bad
# 4         bad
# ..        ...
# 557      good
# 558      good
# 559      good
# 560      good
# 561      good
#
# [396 rows x 23 columns]

# %%
df_id_name = combined_df[['id', 'name']]

df_powerstats = combined_df[['id', 'intelligence', 'strength', 'speed', 'durability', 'power', 'combat', 'Overall PS']]

df_appearance = combined_df[['id', 'gender', 'race', 'height', 'weight']]

df_biography = combined_df[['id','firstAppearance', 'publisher', 'alignment']]

# %%
df_powerstats.columns = df_powerstats.columns.str.capitalize()
df_powerstats
# Out:
#       Id  Intelligence  Strength  Speed  Durability  Power  Combat  Overall ps
# 0      1            38       100     17          80     24      64         323
# 1      2            88        28     35          65    100      85         401
# 2      3            50        90     53          64     99      65         421
# 3      4            63        80     53          90     62      95         443
# 4      5            88        63     83         100    100      55         489
# ..   ...           ...       ...    ...         ...    ...     ...         ...
# 557  726            88        10     12          28     12      14         164
# 558  727            50        10     35          28     31      28         182
# 559  728            50       100     27         100     98      28         403
# 560  729            88        52     33          25    100      90         388
# 561  730            81        10     23          28    100      56         298
#
# [396 rows x 8 columns]

# %%
df_appearance.columns = df_appearance.columns.str.capitalize()

def extract_numeric_with_units(text):
    if text is None:
        return ''
    matches = re.findall(r'\d+\s*[a-zA-Z]+', text)
    return matches[0] if matches else ''

df_appearance.loc[:, 'Height'] = df_appearance['Height'].apply(extract_numeric_with_units)
df_appearance.loc[:, 'Weight'] = df_appearance['Weight'].apply(extract_numeric_with_units)

# %%
df_appearance

# %%
df_biography.columns = df_biography.columns.str.capitalize()

# %%
df_biography_copy = df_biography.copy()

df_biography_copy.rename(columns={'Firstappearance': 'First_appearance'}, inplace=True)

# %%
df_biography = df_biography_copy

# %%
df_biography

# %%
def extract_year(appearance):
    year_pattern = r'\b\d{4}\b'
    match = re.search(year_pattern, appearance)
    
    if match:
        return match.group()
    else:
        return None

if 'First_appearance' in df_biography.columns:
    df_biography['Year'] = df_biography['First_appearance'].apply(extract_year)
else:
    print("not found")

# %%
df_biography.drop(columns=['First_appearance'], inplace=True)
df_biography

# %%
#df_id_name.to_csv('id_name.csv', index=False)
#df_powerstats.to_csv('powerstats.csv', index=False)
#df_appearance.to_csv('appearance.csv', index=False)
#df_biography.to_csv('biography.csv', index=False)

# %%
df_biography['Year'] = df_biography['Year'].replace('2099', '1993')
df_biography.Year.unique()
